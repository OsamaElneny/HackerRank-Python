# %% [markdown]
# ![image.png](attachment:84a55413-ead4-482a-9b33-fdb76bf45ecd.png)
# ![image.png](attachment:ed80dc0a-5c55-444f-8335-b03ba09a8239.png)

# %% [markdown]
# # Solution:

# %%
n = int(input().strip())
if 1 <= n <= 150:
    for i in range(1, n + 1):
        print(i, end='')
# Out:
#  3
# 123

# %% [markdown]
# ![image.png](attachment:b986c2fe-f027-4018-8445-b75d7bf5ccfc.png)
# ![image.png](attachment:3ac4548d-47bb-4d8b-8c4d-ff43c7ec2ba2.png)

# %% [markdown]
# # Solution:

# %%
def is_leap(year):
    if year % 400 == 0:
        return True

    if year % 100 == 0:
        return False

    if year % 4 == 0:
        return True

    return False

year = int(input().strip())
print(is_leap(year))
# Out:
#  1990
# False

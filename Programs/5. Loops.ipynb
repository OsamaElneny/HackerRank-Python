# %% [markdown]
# ![image.png](attachment:b65d030d-74f1-4a6d-a1c0-36c499669803.png)
# ![image.png](attachment:0b94501a-4167-4e22-ae1d-03b8db850132.png)

# %% [markdown]
# # Solution:

# %%
n = int(input().strip())
if 1 <= n <= 20:
    for i in range(n):
        print(i ** 2)
# Out:
#  5
# 0
# 1
# 4
# 9
# 16

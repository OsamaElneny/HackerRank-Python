# %% [markdown]
# ![image.png](attachment:07006ef1-dabf-4429-bc4d-1af8aaf06a1f.png)
# ![image.png](attachment:42d8960a-3a19-4dd0-b093-593d01125dec.png)
# ![image.png](attachment:f15f86d0-0b68-4e1d-8558-b1f33c417256.png)

# %% [markdown]
# # Solution:

# %%
def mutate_string(string, position, character):
    
    return string[:position] + character + string[position+1:]


s = input()
i, c = input().split()
i = int(i)
print(mutate_string(s, i, c))
# Out:
#  abracadabra
#  5 k
# abrackdabra

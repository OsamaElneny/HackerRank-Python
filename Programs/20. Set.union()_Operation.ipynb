# %% [markdown]
# ![image.png](attachment:2440ea2d-9651-4d07-a6e1-6124ac85c935.png)
# ![image.png](attachment:110b9d46-9793-4942-bf62-540535fbd3ac.png)
# ![image.png](attachment:59f65d20-89dd-4c01-a407-82c9313ee8e5.png)

# %% [markdown]
# # Solution:

# %%
def set_union_count(english, french):

    return len(english.union(french))

n_eng = int(input().strip())
english = set(map(int, input().split()))

n_fre = int(input().strip())
french = set(map(int, input().split()))

print(set_union_count(english, french))
# Out:
#  9
#  1 2 3 4 5 6 7 8 9
#  9
#  10 1 2 3 11 21 55 6 8
# 13

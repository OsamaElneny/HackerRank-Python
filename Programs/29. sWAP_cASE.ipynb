# %% [markdown]
# ![image.png](attachment:707de4e3-c179-4eaf-b0b9-2eb8f6536565.png)
# ![image.png](attachment:939eaefc-4c8c-4d7d-a264-63361761601b.png)

# %% [markdown]
# # Solution:

# %%
def swap_case(s):
   
    return s.swapcase()

s = input()
print(swap_case(s))
# Out:
#  HackerRank.com presents "Pythonist 2".
# hACKERrANK.COM PRESENTS "pYTHONIST 2".

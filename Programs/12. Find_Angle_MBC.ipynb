# %% [markdown]
# ![image.png](attachment:d81c9e66-18da-45aa-8f1f-cd5c993367db.png)
# ![image.png](attachment:d4ae42d7-192d-49a8-bf59-3bf3c537c381.png)

# %% [markdown]
# # Solution:

# %%
import math

def find_angle(ab, bc):
   
    angle_rad = math.atan(ab / bc)       
    angle_deg = round(math.degrees(angle_rad))
    return f"{angle_deg}\N{DEGREE SIGN}"   

AB = int(input().strip())
BC = int(input().strip())
print(find_angle(AB, BC))
# Out:
#  10
#  10
# 45°

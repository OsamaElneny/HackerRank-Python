# %% [markdown]
# ![image.png](attachment:5c0cd9f4-47ce-4c15-a00f-b38bf12ada4e.png)
# ![image.png](attachment:8985dcd9-3643-4dbf-a340-8f653bb8009c.png)

# %% [markdown]
# # Solution:

# %%
n = int(input().strip())

if (n % 2 != 0) or (n % 2 == 0 and n in range(6, 21)):
    print("Weird")
elif (n % 2 == 0 and n in range(2, 6)) or (n % 2 == 0 and n > 20):
    print("Not Weird")
# Out:
#  3
# Weird

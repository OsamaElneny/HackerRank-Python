# %% [markdown]
# ![image.png](attachment:b78344b6-7d0b-4b84-9f7b-d577faf1abf9.png)
# ![image.png](attachment:5fa58507-789c-441d-9436-018dd5360936.png)

# %% [markdown]
# # Solution:

# %%
def triangle_quest_2(n):
  
    return [((10**i - 1) // 9) ** 2 for i in range(1, n + 1)]

n = int(input().strip())
print(*triangle_quest_2(n), sep="\n")
# Out:
#  5
# 1
# 121
# 12321
# 1234321
# 123454321

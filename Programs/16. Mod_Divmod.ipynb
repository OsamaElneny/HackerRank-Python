# %% [markdown]
# ![image.png](attachment:61a19f36-1c51-4483-b5c1-363d4124dce7.png)
# ![image.png](attachment:228394bb-801c-49f7-9439-578de49e32bb.png)

# %% [markdown]
# # Solution:

# %%
def mod_divmod(a, b):
   
    return a // b, a % b, divmod(a, b)


a = int(input().strip())
b = int(input().strip())

div, mod, divmod_result = mod_divmod(a, b)

print(div)
print(mod)
print(divmod_result)
# Out:
#  177
#  10
# 17
# 7
# (17, 7)

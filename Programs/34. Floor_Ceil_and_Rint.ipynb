# %% [markdown]
# ![image.png](attachment:3981e23f-85fe-419a-a443-1ff350dd30ef.png)
# ![image.png](attachment:76995478-e101-48e1-85d8-1ef95c78cf40.png)

# %% [markdown]
# # Solution:

# %%
import numpy as np
np.set_printoptions(legacy='1.13')
def main():
    arr = np.array(list(map(float, input().split())))  # e.g. "1.2 2.5 ..."
    
    print(np.floor(arr))
    print(np.ceil(arr))
    print(np.rint(arr))


main()
# Out:
#   1.23 4.44 5.66 3.77
# [ 1.  4.  5.  3.]
# [ 2.  5.  6.  4.]
# [ 1.  4.  6.  4.]

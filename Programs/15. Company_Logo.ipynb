# %% [markdown]
# ![image.png](attachment:7050cf22-fce5-416f-ae29-d222818bc6d4.png)
# ![image.png](attachment:c9374c6d-3005-4259-84f5-9388aaf514cc.png)

# %% [markdown]
# # Solution:

# %%
from collections import Counter

def top_three_most_common(s):
  
    counts = Counter(s)

    items = sorted(counts.items(), key=lambda item: (-item[1], item[0]))

    return items[:3]


s = input().strip()
for ch, cnt in top_three_most_common(s):
    print(ch, cnt)
# Out:
#   aabbbccde
# b 3
# a 2
# c 2

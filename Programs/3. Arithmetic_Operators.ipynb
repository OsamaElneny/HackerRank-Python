# %% [markdown]
# ![image.png](attachment:8d6a2814-322d-42cf-9f28-2c2ddfff95cb.png)
# ![image.png](attachment:899c9813-3852-48a8-9a84-08d1d8951548.png)

# %% [markdown]
# # Solution:

# %%
a = int(input().strip())
b = int(input().strip())

print(a + b)
print(a - b)
print(a * b)
# Out:
#  3
#  5
# 8
# -2
# 15

# %% [markdown]
# ![image.png](attachment:0af0f88a-ea3c-432c-a5b5-9d331b8e6c54.png)
# ![image.png](attachment:14460a72-48fa-4a8c-a254-b557b6e77486.png)

# %% [markdown]
# # Solution:

# %%
def captain_room(k, rooms):
  
    return (k * sum(set(rooms)) - sum(rooms)) // (k - 1)

k = int(input().strip())
rooms = list(map(int, input().split()))
print(captain_room(k, rooms))
# Out:
#  5
#   1 2 3 6 5 4 4 2 5 3 6 1 6 5 3 2 4 1 2 5 1 4 3 6 8 4 3 1 5 6 2
# 8

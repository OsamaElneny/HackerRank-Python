# %% [markdown]
# ![image.png](attachment:5b73b934-02bb-46f8-9689-222ab2ff7f42.png)
# ![image.png](attachment:713e9654-78c0-4274-aaee-396409add1f3.png)

# %% [markdown]
# # Solution:

# %%
def power_mod_power(a, b, m):
    
    return pow(a, b), pow(a, b, m)

a = int(input().strip())
b = int(input().strip())
m = int(input().strip())

result, mod_result = power_mod_power(a, b, m)

print(result)
print(mod_result)
# Out:
#  3
#  4
#  5
# 81
# 1

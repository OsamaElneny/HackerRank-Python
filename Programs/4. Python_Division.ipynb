# %% [markdown]
# ![image.png](attachment:f399380e-aaaa-47c3-8fce-32591500a605.png)
# ![image.png](attachment:b1f1e254-45c8-4165-aa15-bc4018d30228.png)

# %% [markdown]
# # Solution:

# %%
a = int(input().strip())
b = int(input().strip())

print(a // b)

print(a / b)
# Out:
#  4
#  3
# 1
# 1.3333333333333333

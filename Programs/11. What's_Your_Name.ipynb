# %% [markdown]
# ![image.png](attachment:898395a3-294d-4b77-86fe-a159e993f377.png)
# ![image.png](attachment:21178589-5ebc-4aaa-89b8-981696a53120.png)

# %% [markdown]
# # Solution:

# %%
def print_full_name(first, last):
    
    print(f"Hello {first} {last}! You just delved into python.")

first = input().strip()
last = input().strip()
print_full_name(first, last)
# Out:
#  Ross
#  Tylor
# Hello Ross Tylor! You just delved into python.

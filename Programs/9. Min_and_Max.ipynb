# %% [markdown]
# ![image.png](attachment:f4701605-a4ac-43ae-9ae2-7804370e5d50.png)
# ![image.png](attachment:d024ab53-ca48-46b2-bd0e-042ed4c94599.png)
# ![image.png](attachment:b34cf50c-9801-46cd-ac8c-861b9c93632f.png)

# %% [markdown]
# # Solution:

# %%
import numpy as np

N, M = map(int, input().split())
A = np.array([input().split() for _ in range(N)], int)
print(f"The Max of the Min values is > {np.max(np.min(A, axis=1))}")
# Out:
#  4 2
#  1 2
#  3 4
#  5 6
#  3 4
# The Max of the Min values is > 5

# %% [markdown]
# ![image.png](attachment:afef9bf2-c75c-4cf8-b6bf-3fd0ca6bf109.png)
# ![image.png](attachment:4312dc7e-dfa1-480d-accb-872aa3b0af4d.png)
# ![image.png](attachment:7d208242-48e6-4c2d-be66-b22df1f31015.png)

# %% [markdown]
# # Solution:

# %%
def set_difference_count(english, french):
  
    return len(english - french)  

n_eng = int(input().strip())
english = set(map(int, input().split()))

n_fre = int(input().strip())
french = set(map(int, input().split()))

print(set_difference_count(english, french))
# Out:
#  9
#  1 2 3 4 5 6 7 8 9
#  9
#  10 1 2 3 11 21 55 6 8
# 4

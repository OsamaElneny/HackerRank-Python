# %% [markdown]
# ![image.png](attachment:defc4a16-091f-48dc-a171-c8944e019483.png)
# ![image.png](attachment:9a98bbb9-dd35-4c83-a016-7f3c44cad766.png)

# %% [markdown]
# # Solution:

# %%
def integers_come_in_all_sizes(a, b, c, d):
    
    return pow(a, b) + pow(c, d)

a = int(input().strip())
b = int(input().strip())
c = int(input().strip())
d = int(input().strip())

print(integers_come_in_all_sizes(a, b, c, d))
# Out:
#  9
#  29
#  7
#  27
# 4710194409608608369201743232

# %% [markdown]
# ![image.png](attachment:37a84a5c-e29a-4177-b783-1c1fd187fa4a.png)
# ![image.png](attachment:ab97aba6-4096-4e70-a24f-d9d785994577.png)

# %% [markdown]
# # Solution:

# %%
def split_and_join(line):
  
    return "-".join(line.split())

line = input()
print(split_and_join(line))
# Out:
#  this is a string
# this-is-a-string

# %% [markdown]
# ![image.png](attachment:2e2fed8a-e3be-4244-bd5d-d91d33cce1b1.png)
# ![image.png](attachment:47fe19d3-6351-4bcc-9f3b-51952d0e22b0.png)

# %% [markdown]
# # Solution:

# %%
for i in range(1, int(input())): 
    print(i * ((10**i - 1)//9))
# Out:
#  5
# 1
# 22
# 333
# 4444

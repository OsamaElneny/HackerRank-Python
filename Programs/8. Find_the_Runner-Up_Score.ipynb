# %% [markdown]
# ![image.png](attachment:455045bb-9663-4afe-9f09-d866aeeabc07.png)
# ![image.png](attachment:1f96850d-0a9c-4bc2-bb35-832330a7af55.png)

# %% [markdown]
# # Solution:

# %%
n = int(input())
arr = list(map(int, input().split()))

unique_scores = list(set(arr))

unique_scores.sort(reverse=True)

print(unique_scores[1])
# Out:
#  5
#  2 2 6 6 5
# 5
